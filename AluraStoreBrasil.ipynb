# %% [markdown]
# <a href="https://colab.research.google.com/github/tama9-ball/challenge-alura-store/blob/main/AluraStoreBrasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação dos dados:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
def formatador_reais(valor, pos):
  return f'R${valor:,.0f}'
formatador = FuncFormatter(formatador_reais) #transforma notação científica em decimal

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
faturamento1 = loja['Preço'].sum()
faturamento2 = loja2['Preço'].sum()
faturamento3 = loja3['Preço'].sum()
faturamento4 = loja4['Preço'].sum()
dados_faturamento = pd.Series([faturamento1, faturamento2, faturamento3, faturamento4], index = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'])

# %%
print(f'Faturamento da Loja 1: {faturamento1}')
print(f'Faturamento da Loja 2: {faturamento2}')
print(f'Faturamento da Loja 3: {faturamento3}')
print(f'Faturamento da Loja 4: {faturamento4}')
# Out:
# Faturamento da Loja 1: 1534509.12
# Faturamento da Loja 2: 1488459.06
# Faturamento da Loja 3: 1464025.03
# Faturamento da Loja 4: 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
cat_mais_vendido1 = loja.groupby('Categoria do Produto').size()
cat_mais_vendido2 = loja2.groupby('Categoria do Produto').size()
cat_mais_vendido3 = loja3.groupby('Categoria do Produto').size()
cat_mais_vendido4 = loja4.groupby('Categoria do Produto').size()
categorias_dados = pd.DataFrame({'Loja 1': cat_mais_vendido1, 'Loja 2': cat_mais_vendido2,'Loja 3': cat_mais_vendido3,'Loja 4': cat_mais_vendido4})

# %%
print(f'Categoria de produto mais vendida na loja 1: \n{cat_mais_vendido1.to_string()}')
print(f'\nCategoria de produto mais vendida na loja 2: \n{cat_mais_vendido2.to_string()}')
print(f'\nCategoria de produto mais vendida na loja 3: \n{cat_mais_vendido3.to_string()}')
print(f'\nCategoria de produto mais vendida na loja 4: \n{cat_mais_vendido4.to_string()}')
# Out:
# Categoria de produto mais vendida na loja 1:
# Categoria do Produto
# brinquedos               324
# eletrodomesticos         312
# eletronicos              448
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# moveis                   465
# utilidades domesticas    171
#
# Categoria de produto mais vendida na loja 2:
# Categoria do Produto
# brinquedos               313
# eletrodomesticos         305
# eletronicos              422
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# moveis                   442
# utilidades domesticas    181
#
# Categoria de produto mais vendida na loja 3:
# Categoria do Produto
# brinquedos               315
# eletrodomesticos         278
# eletronicos              451
# esporte e lazer          277
# instrumentos musicais    177
# livros                   185
# moveis                   499
# utilidades domesticas    177
#
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_loja1 = loja['Avaliação da compra'].mean()
media_loja2 = loja2['Avaliação da compra'].mean()
media_loja3 = loja3['Avaliação da compra'].mean()
media_loja4 = loja4['Avaliação da compra'].mean()
dados_avaliacoes = pd.Series([media_loja1, media_loja2, media_loja3, media_loja4], index=['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'])

# %%
print(f'Média de avaliações da Loja 1: {media_loja1}')
print(f'Média de avaliações da Loja 2: {media_loja2}')
print(f'Média de avaliações da Loja 3: {media_loja3}')
print(f'Média de avaliações da Loja 4: {media_loja4}')
# Out:
# Média de avaliações da Loja 1: 3.976685036032217
# Média de avaliações da Loja 2: 4.037303942348453
# Média de avaliações da Loja 3: 4.048325561678677
# Média de avaliações da Loja 4: 3.9957591178965224

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
mais_vendido1 = loja.groupby('Produto').size().sort_values(ascending=False).head(5)
menos_vendido1 = loja.groupby('Produto').size().sort_values(ascending=False).tail(5)

mais_vendido2 = loja2.groupby('Produto').size().sort_values(ascending=False).head(5)
menos_vendido2 = loja2.groupby('Produto').size().sort_values(ascending=False).tail(5)

mais_vendido3 = loja3.groupby('Produto').size().sort_values(ascending=False).head(5)
menos_vendido3 = loja3.groupby('Produto').size().sort_values(ascending=False).tail(5)

mais_vendido4 = loja4.groupby('Produto').size().sort_values(ascending=False).head(5)
menos_vendido4 = loja4.groupby('Produto').size().sort_values(ascending=False).tail(5)

# %%
print(f'Produtos mais vendidos Loja 1: \n {mais_vendido1.to_string()}')
print(f'\nProdutos menos vendidos Loja 1: \n {menos_vendido1.to_string()}')
print('_________________________________')
print(f'\nProdutos mais vendidos Loja 2: \n {mais_vendido2.to_string()}')
print(f'\nProdutos menos vendidos Loja 2: \n {menos_vendido2.to_string()}')
print('_________________________________')
print(f'\nProdutos mais vendidos Loja 3: \n {mais_vendido3.to_string()}')
print(f'\nProdutos menos vendidos Loja 3: \n {menos_vendido3.to_string()}')
print('_________________________________')
print(f'\nProdutos mais vendidos Loja 4: \n {mais_vendido4.to_string()}')
print(f'\nProdutos menos vendidos Loja 4: \n {menos_vendido4.to_string()}')
# Out:
# Produtos mais vendidos Loja 1:
#  Produto
# TV Led UHD 4K         60
# Micro-ondas           60
# Guarda roupas         60
# Secadora de roupas    58
# Blocos de montar      56
#
# Produtos menos vendidos Loja 1:
#  Produto
# Ciência de dados com python    39
# Pandeiro                       36
# Panela de pressão              35
# Celular ABXY                   33
# Headset                        33
# _________________________________
#
# Produtos mais vendidos Loja 2:
#  Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
#
# Produtos menos vendidos Loja 2:
#  Produto
# Fone de ouvido       37
# Poltrona             35
# Impressora           34
# Mesa de jantar       34
# Jogo de tabuleiro    32
# _________________________________
#
# Produtos mais vendidos Loja 3:
#  Produto
# Kit banquetas      57
# Mesa de jantar     56
# Cama king          56
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_media_loja1 = loja['Frete'].mean()
frete_media_loja2 = loja2['Frete'].mean()
frete_media_loja3 = loja3['Frete'].mean()
frete_media_loja4 = loja4['Frete'].mean()
dados_frete = pd.Series([frete_media_loja1, frete_media_loja2, frete_media_loja3, frete_media_loja4], index = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'])

# %%
print(f'Média de frete da Loja 1: {frete_media_loja1}')
print(f'Média de frete da Loja 2: {frete_media_loja2}')
print(f'Média de frete da Loja 3: {frete_media_loja3}')
print(f'Média de frete da Loja 4: {frete_media_loja4}')
# Out:
# Média de frete da Loja 1: 34.69180491551149
# Média de frete da Loja 2: 33.62194065817927
# Média de frete da Loja 3: 33.07446427411743
# Média de frete da Loja 4: 31.278997081841727

# %% [markdown]
# # Visualização (Gráficos)

# %% [markdown]
# #Média de faturamento de cada loja

# %%
grf1 = dados_faturamento.plot(kind = 'bar', title = 'Faturamento total por loja', rot = 0, figsize = (10, 6)) #gera o gráfico
grf1.yaxis.set_major_formatter(formatador)

for barra in grf1.patches: #coloca o valor exato em cima de cada barra
    valor = barra.get_height()
    texto_valor = f'R${valor:,.0f}'

    grf1.annotate(texto_valor, (barra.get_x() + barra.get_width() / 2, valor), ha='center', va='bottom', xytext=(0, 2), textcoords='offset points')

# %% [markdown]
# Embora a diferença do faturamento entre as lojas seja majoritamente bem sutil, é notável a diferença entre a Loja 1 e a Lojaa 4: a Loja 4 está R$150,011 atrás, sendo de longe a menos lucrativa entre as 4. A diferença entre a Loja 3 e a 4 é de R$79,527.

# %% [markdown]
# # Frete médio entre as lojas

# %%
plt.figure(figsize =(10,6)) #gera o gráfico
plt.stem(dados_frete.index, dados_frete.values)
plt.title('Frete Médio por Loja')
plt.ylabel('Custo Médio do Frete (R$)')
plt.xlabel('Loja')
plt.gca().yaxis.set_major_formatter(formatador)

for i, media_valor in enumerate(dados_frete.values): #adiciona o valor exaato pra cada ponto
    plt.text( x=i, y=media_valor + 0.5, s=f'R${media_valor:.2f}', ha='center', va='bottom', fontsize=7)

plt.show()

# %% [markdown]
# A Loja 1, embora tenha o maior faturamento, têm também a média de frete mais alta. A diferença entre as Lojas 2 e 3, como no faturamento, é bem sutil, e a média de frete da Loja 4 é notavelmente mais baixa que às demais.

# %% [markdown]
# A Loja 1

# %% [markdown]
# # Categorias mais vendidas em cada loja

# %%
comparacao_categorias = categorias_dados.T

grf_cat = comparacao_categorias.plot(kind='bar',figsize=(15, 7), title='Comparação entre Categorias em cada Loja', rot=0) #gera o gráfico
grf_cat.legend(title='Categorias de Produtos', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.ylabel('Quantidade Vendida')
plt.xlabel('Lojas')
#abaixo, adiciona os valores totais
for barra in grf_cat.patches: grf_cat.annotate(f'{barra.get_height():.0f}', (barra.get_x() + barra.get_width() / 2, barra.get_height()), ha='center', va='bottom', xytext=(0, 5), textcoords='offset points')

# %% [markdown]
# Em todas as lojas, as categorias mais compradas, são de longe Moveis e Eletrônicos. A Loja 2 tem o maior equilíbrio entre todas as categorias, e teve o "chão" de consumo mais baixo: sua categoria menos vendida teve uma quantidade de vendas comparável com a quantidade de vendas da segunda/terceira categoria menos vendida das demais.
#
# Volume Loja 1: 2.359 itens
#
# Volume Loja 2: 2.359 itens
#
# Volume Loja 3: 2.359 itens
#
# Volume Loja 4: 2.358 itens

# %% [markdown]
# # Médias de avaliação de cada loja

# %%
plt.figure(figsize=(10, 6)) #gera o gráfico
plt.scatter(y=dados_avaliacoes.values, x=dados_avaliacoes.index, s=150)
plt.title('Média de Avaliação por Loja')
plt.xlabel('Nota Média (1-5)')
plt.ylabel('Loja')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.ylim(3.5, 4.7)

for i, (loja_nome, media_valor) in enumerate(dados_avaliacoes.items()): #adiciona o valor exato pra cada ponto
    plt.text(y=media_valor + 0.05, x=i, s=f'{media_valor:.2f}', va='center',fontsize=12)

plt.show()

# %% [markdown]
# A Loja 1, que tem a média de frete mais alta, têm também a avaliação mais baixa entre todas as lojas, com a Loja 4 logo acima. Novamente vemos bastante equilibrio entre as Lojas 2 e 3.

# %% [markdown]
# # Relatorio Final

# %% [markdown]
# As Lojas 2 e 3 são o padrão de ouro: avaliações decentes, frete moderado e bom faturamento. Há muito equillibrio entre as duas, o que nos deixa com as Lojas 1 e 4: A Loja 1, embora tenha o maior faturamento, acaba sendo a loja mais " instável", com a menor avaliação (abaixo de 4 estrelas) e de longe a maior média de frete. Já a Loja 4, embora tenha o menor faturmento, é definitivamente mais estável, possuindo o menor valor de frete e uma avaliação decente.
#
# Já que a quantidade vendas é bastante similar entre todas as lojas, pressuponho que o motivo do faturamento baixo da Loja 4 seja os produtos vendidos: calculando o faturamento com o total de vendas, chega-se à conclusão de que a média de valor dos produtos vendidos na Loja 4 é baixo. Com a estratégia de vendas e marketing correto, imagino que a Loja 4 tenha o potenncial para alcançar ou até mesmo superar as outras lojas, sendo esta então a minha sugestão para o Sr. João.
